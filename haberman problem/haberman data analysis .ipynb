# %% [markdown]
# ## Haberman dataset Analysis

# %% [markdown]
# ### Haberman Dataset

# %% [markdown]
# ### Attribute Information
#
# 1. Age of patient at time of operation (numerical)
# 2. Patient's year of operation (year - 1900, numerical)
# 3. Number of positive axillary nodes detected (numerical)
# 4. Survival status (class attribute)
#   1. 1 = the patient survived 5 years or longer
#   2. 2 = the patient died within 5 year

# %% [markdown]
# #### Importing data

# %%
import pandas as pd

haberman_data_path = 'haberman.csv'
hm = pd.read_csv(haberman_data_path)
print(hm.shape)
print(hm.columns)
# Out:
# (305, 4)
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
hm.head(5)
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
hm.status.value_counts()
# Out:
# 1    225
# 2     80
# Name: status, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.close()
sns.set_style("whitegrid")
sns.pairplot(hm, hue="status", vars=['age', 'year', 'nodes'], size=4)
plt.show()
